# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv("data3/LifeExpectancyData.csv")

# %%
df.columns = df.columns.str.replace(' ', '_')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life_expectancy_                 2928 non-null   float64
#  4   Adult_Mortality                  2928 non-null   float64
#  5   infant_deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage_expenditure           2938 non-null   float64
#  8   Hepatitis_B                      2385 non-null   float64
#  9   Measles_                         2938 non-null   int64
#  10  _BMI_                            2904 non-null   float64
#  11  under-five_deaths_               2938 non-null   int64
# ...

# %%
from matplotlib import pyplot
import seaborn as sb
corr = df.corr()
fig, ax = pyplot.subplots(figsize=(18,18))
sb.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %%
corr = df.corr()
fig, ax = pyplot.subplots(figsize=(18,18))
sb.scatterplot(data=df, x='Schooling', y='Life_expectancy_')
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Life_expectancy_'>
